# %%
print("hello world")
# Out:
# hello world

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# 1. Load the image
image_path = "/home/mohamed-alwathiq/Downloads/dish.jpg"
image = cv2.imread(image_path)
# OpenCV loads in BGR, Matplotlib expects RGB. Convert for displaying.
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# 2. Convert to Grayscale
# Math is faster and simpler on a 2D black-and-white array
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# 3. Apply Gaussian Blur
# This smooths out microscopic dust so the computer doesn't overcount
blurred = cv2.GaussianBlur(gray, (15, 15), 0)

# %%
# 4. Otsu's Thresholding
# This automatically calculates the best lighting threshold to turn the image 
# into pure black (background) and pure white (colonies)
_, thresh = cv2.threshold(blurred, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# 5. Find Contours
# The algorithm traces the boundaries of the white blobs
contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# 6. Filter by size and draw
min_area = 50  # Ignore tiny specs
valid_colonies = [c for c in contours if cv2.contourArea(c) > min_area]

# Draw red outlines around detected colonies on a copy of the original image
output_image = image_rgb.copy()
cv2.drawContours(output_image, valid_colonies, -1, (255, 0, 0), 2)

print(f"Total isolated colonies detected: {len(valid_colonies)}")
# Out:
# Total isolated colonies detected: 3

# %%
# 7. Visualize the pipeline
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

axs[0].imshow(image_rgb)
axs[0].set_title("1. Original Image")
axs[0].axis("off")

axs[1].imshow(thresh, cmap="gray")
axs[1].set_title("2. Binary Threshold (What the computer sees)")
axs[1].axis("off")

axs[2].imshow(output_image)
axs[2].set_title(f"3. Detections: {len(valid_colonies)} Colonies")
axs[2].axis("off")

plt.show()

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
import cv2

# 1. Load the pre-trained Nano model (downloads automatically the first time)
model = YOLO("yolo11n.pt")

# 2. Run inference on your sample image
# We set conf=0.1 just to see everything the model *thinks* it sees
results = model(image_path, conf=0.1)

# 3. Extract the image with the bounding boxes drawn on it
annotated_image = results[0].plot()

# 4. Display the result using Matplotlib
# Convert BGR (OpenCV format) to RGB (Matplotlib format)
annotated_image_rgb = cv2.cvtColor(annotated_image, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10, 10))
plt.imshow(annotated_image_rgb)
plt.axis("off")
plt.title("Pre-trained YOLOv11-Nano Output")
plt.show()
# Out:
# image 1/1 /home/mohamed-alwathiq/Downloads/dish.jpg: 480x640 1 bowl, 1 dining table, 1 clock, 139.8ms
# Speed: 6.2ms preprocess, 139.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)

# %%
# !pip install ollama
import ollama
import json
# Out:
# Collecting ollama
#   Downloading ollama-0.6.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: httpx>=0.27 in /home/mohamed-alwathiq/lablens_env/lib/python3.12/site-packages (from ollama) (0.28.1)
# Collecting pydantic>=2.9 (from ollama)
#   Downloading pydantic-2.13.4-py3-none-any.whl.metadata (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.4/109.4 kB 425.2 kB/s eta 0:00:001m359.8 kB/s eta 0:00:01
# Requirement already satisfied: anyio in /home/mohamed-alwathiq/lablens_env/lib/python3.12/site-packages (from httpx>=0.27->ollama) (4.13.0)
# Requirement already satisfied: certifi in /home/mohamed-alwathiq/lablens_env/lib/python3.12/site-packages (from httpx>=0.27->ollama) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /home/mohamed-alwathiq/lablens_env/lib/python3.12/site-packages (from httpx>=0.27->ollama) (1.0.9)
# Requirement already satisfied: idna in /home/mohamed-alwathiq/lablens_env/lib/python3.12/site-packages (from httpx>=0.27->ollama) (3.16)
# Requirement already satisfied: h11>=0.16 in /home/mohamed-alwathiq/lablens_env/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27->ollama) (0.16.0)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.9->ollama)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.4 (from pydantic>=2.9->ollama)
#   Downloading pydantic_core-2.46.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: typing-extensions>=4.14.1 in /home/mohamed-alwathiq/lablens_env/lib/python3.12/site-packages (from pydantic>=2.9->ollama) (4.15.0)
# Collecting typing-inspection>=0.4.2 (from pydantic>=2.9->ollama)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Downloading ollama-0.6.2-py3-none-any.whl (15 kB)
# Downloading pydantic-2.13.4-py3-none-any.whl (472 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.3/472.3 kB 1.3 MB/s eta 0:00:001.2 MB/s eta 0:00:01m
# Downloading pydantic_core-2.46.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 2.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Installing collected packages: typing-inspection, pydantic-core, annotated-types, pydantic, ollama
# Successfully installed annotated-types-0.7.0 ollama-0.6.2 pydantic-2.13.4 pydantic-core-2.46.4 typing-inspection-0.4.2

# %%
# 1. Mock the Data (This simulates the output we will eventually get from OpenCV + YOLO)
# We format it as a JSON string because LLMs parse structured data very well.
mock_vision_data = {
    "colony_count": 84,
    "contaminants": 1,
    "density_flag": "High"
}

vision_json_string = json.dumps(mock_vision_data)

# 2. Design the System Prompt
# This tells the Qwen model exactly how to behave and formats its output.
system_prompt = """
You are LabLens, an AI-powered microbiology assistant. 
Your job is to read raw JSON sensor data from a petri dish analysis and generate a concise, professional lab notebook entry.
Format the output with clear bullet points. Do not include conversational filler.
"""

print("Sending mocked JSON data to local Qwen2.5-1.5B model...\n")

# 3. Call the Local LLM
response = ollama.chat(model='qwen2.5:1.5b', messages=[
  {
    'role': 'system',
    'content': system_prompt
  },
  {
    'role': 'user',
    'content': f"Here is the latest sensor data: {vision_json_string}"
  }
])

# 4. Display the Output
print("====== GENERATED LAB NOTES ======")
print(response['message']['content'])
print("=================================")
# Out:
# Sending mocked JSON data to local Qwen2.5-1.5B model...
#
# ====== GENERATED LAB NOTES ======
# **Lab Notebook Entry**
#
# **Date:** [Insert Date Here]
#
# **Colony Count:** The current petri dish has recorded a colony count of **84 colonies**, indicating an increase in microbial activity or growth within the sample.
#
# **Contaminants Detected:** The sensor data indicates that there is one detected contaminant present, though this does not necessarily imply a contamination risk. However, due to the high density flag set by the system (High), further investigation may be necessary to assess potential risks associated with the presence of contaminants in the culture.
#
# **Environmental Conditions and Observations:**
# - The temperature within the petri dish is stable at [Insert Temperature Here] degrees Celsius.
# - The humidity level is maintained between 60% and 75%, suitable for optimal microbial growth conditions.
#
# This data suggests that the environment is conducive to microbial proliferation, warranting additional precautions or monitoring of the sample's health.
# =================================

# %%
pip install -U inference-sdk
# Out:
# Collecting inference-sdk
#   Downloading inference_sdk-1.2.10-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: requests<3.0.0,>=2.33.0 in /home/mohamed-alwathiq/lablens_env/lib/python3.12/site-packages (from inference-sdk) (2.34.2)
# Collecting dataclasses-json~=0.6.0 (from inference-sdk)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting opencv-python<=4.10.0.84,>=4.8.1.78 (from inference-sdk)
#   Downloading opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: pillow<13.0.0,>=12.2.0 in /home/mohamed-alwathiq/lablens_env/lib/python3.12/site-packages (from inference-sdk) (12.2.0)
# Collecting supervision>=0.26 (from inference-sdk)
#   Downloading supervision-0.28.0-py3-none-any.whl.metadata (14 kB)
# Collecting numpy<2.4.0,>=2.0.0 (from inference-sdk)
#   Downloading numpy-2.3.5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 698.8 kB/s eta 0:00:001m713.2 kB/s eta 0:00:01
# Collecting aiohttp~=3.13.3 (from inference-sdk)
#   Downloading aiohttp-3.13.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.1 kB)
# Collecting backoff~=2.2.0 (from inference-sdk)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting py-cpuinfo~=9.0.0 (from inference-sdk)
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp~=3.13.3->inference-sdk)
#   Downloading aiohappyeyeballs-2.6.2-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp~=3.13.3->inference-sdk)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in /home/mohamed-alwathiq/lablens_env/lib/python3.12/site-packages (from aiohttp~=3.13.3->inference-sdk) (26.1.0)
# Collecting frozenlist>=1.1.1 (from aiohttp~=3.13.3->inference-sdk)
#   Downloading frozenlist-1.8.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp~=3.13.3->inference-sdk)
#   Downloading multidict-6.7.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp~=3.13.3->inference-sdk)
#   Downloading propcache-0.5.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (16 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp~=3.13.3->inference-sdk)
#   Downloading yarl-1.24.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (94 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.2/94.2 kB 13.8 MB/s eta 0:00:00
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json~=0.6.0->inference-sdk)
#   Downloading marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json~=0.6.0->inference-sdk)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/mohamed-alwathiq/lablens_env/lib/python3.12/site-packages (from requests<3.0.0,>=2.33.0->inference-sdk) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/mohamed-alwathiq/lablens_env/lib/python3.12/site-packages (from requests<3.0.0,>=2.33.0->inference-sdk) (3.16)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/mohamed-alwathiq/lablens_env/lib/python3.12/site-packages (from requests<3.0.0,>=2.33.0->inference-sdk) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /home/mohamed-alwathiq/lablens_env/lib/python3.12/site-packages (from requests<3.0.0,>=2.33.0->inference-sdk) (2026.5.20)
# Requirement already satisfied: defusedxml>=0.7.1 in /home/mohamed-alwathiq/lablens_env/lib/python3.12/site-packages (from supervision>=0.26->inference-sdk) (0.7.1)
# Requirement already satisfied: matplotlib>=3.6 in /home/mohamed-alwathiq/lablens_env/lib/python3.12/site-packages (from supervision>=0.26->inference-sdk) (3.10.9)
# Collecting pydeprecate<0.8,>=0.7 (from supervision>=0.26->inference-sdk)
#   Downloading pydeprecate-0.7.0-py3-none-any.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.3 in /home/mohamed-alwathiq/lablens_env/lib/python3.12/site-packages (from supervision>=0.26->inference-sdk) (6.0.3)
# Requirement already satisfied: scipy>=1.10 in /home/mohamed-alwathiq/lablens_env/lib/python3.12/site-packages (from supervision>=0.26->inference-sdk) (1.17.1)
# Collecting tqdm>=4.62.3 (from supervision>=0.26->inference-sdk)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.2 in /home/mohamed-alwathiq/lablens_env/lib/python3.12/site-packages (from aiosignal>=1.4.0->aiohttp~=3.13.3->inference-sdk) (4.15.0)
# Requirement already satisfied: packaging>=17.0 in /home/mohamed-alwathiq/lablens_env/lib/python3.12/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json~=0.6.0->inference-sdk) (26.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/mohamed-alwathiq/lablens_env/lib/python3.12/site-packages (from matplotlib>=3.6->supervision>=0.26->inference-sdk) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/mohamed-alwathiq/lablens_env/lib/python3.12/site-packages (from matplotlib>=3.6->supervision>=0.26->inference-sdk) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/mohamed-alwathiq/lablens_env/lib/python3.12/site-packages (from matplotlib>=3.6->supervision>=0.26->inference-sdk) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/mohamed-alwathiq/lablens_env/lib/python3.12/site-packages (from matplotlib>=3.6->supervision>=0.26->inference-sdk) (1.5.0)
# Requirement already satisfied: pyparsing>=3 in /home/mohamed-alwathiq/lablens_env/lib/python3.12/site-packages (from matplotlib>=3.6->supervision>=0.26->inference-sdk) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/mohamed-alwathiq/lablens_env/lib/python3.12/site-packages (from matplotlib>=3.6->supervision>=0.26->inference-sdk) (2.9.0.post0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json~=0.6.0->inference-sdk)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: six>=1.5 in /home/mohamed-alwathiq/lablens_env/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.6->supervision>=0.26->inference-sdk) (1.17.0)
# Downloading inference_sdk-1.2.10-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.3/74.3 kB 2.7 MB/s eta 0:00:00
# Downloading aiohttp-3.13.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 2.2 MB/s eta 0:00:002.3 MB/s eta 0:00:01
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading numpy-2.3.5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 1.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 552.4 kB/s eta 0:00:00m eta 0:00:010:00:03
# Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Downloading supervision-0.28.0-py3-none-any.whl (251 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.6/251.6 kB 799.7 kB/s eta 0:00:00MB/s eta 0:00:010:01
# Downloading aiohappyeyeballs-2.6.2-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading frozenlist-1.8.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.4/242.4 kB 954.1 kB/s eta 0:00:00 kB/s eta 0:00:01:01
# Downloading marshmallow-3.26.2-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 2.4 MB/s eta 0:00:00
# Downloading multidict-6.7.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (256 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.3/256.3 kB 1.2 MB/s eta 0:00:001.2 MB/s eta 0:00:01
# Downloading propcache-0.5.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 2.2 MB/s eta 0:00:00
# Downloading pydeprecate-0.7.0-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 1.4 MB/s eta 0:00:001.3 MB/s eta 0:00:01
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 2.3 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading yarl-1.24.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.6/105.6 kB 621.5 kB/s eta 0:00:00 kB/s eta 0:00:011
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Installing collected packages: py-cpuinfo, tqdm, pydeprecate, propcache, numpy, mypy-extensions, multidict, marshmallow, frozenlist, backoff, aiohappyeyeballs, yarl, typing-inspect, opencv-python, aiosignal, dataclasses-json, aiohttp, supervision, inference-sdk
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.4.4
#     Uninstalling numpy-2.4.4:
#       Successfully uninstalled numpy-2.4.4
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.13.0.92
#     Uninstalling opencv-python-4.13.0.92:
#       Successfully uninstalled opencv-python-4.13.0.92
# Successfully installed aiohappyeyeballs-2.6.2 aiohttp-3.13.5 aiosignal-1.4.0 backoff-2.2.1 dataclasses-json-0.6.7 frozenlist-1.8.0 inference-sdk-1.2.10 marshmallow-3.26.2 multidict-6.7.1 mypy-extensions-1.1.0 numpy-2.3.5 opencv-python-4.10.0.84 propcache-0.5.2 py-cpuinfo-9.0.0 pydeprecate-0.7.0 supervision-0.28.0 tqdm-4.67.3 typing-inspect-0.9.0 yarl-1.24.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# 1. Import the library
from inference_sdk import InferenceHTTPClient

# 2. Connect to your workflow
client = InferenceHTTPClient(
    api_url="https://serverless.roboflow.com",
    api_key="UFkIgVDpJOe70zZ80m3R"
)

# 3. Run your workflow on an image
result = client.run_workflow(
    workspace_name="mohamed-alwathiq-s-workspace",
    workflow_id="petri-dish-contamination-detection-1779520779273",
    images={
        "image": "YOUR_IMAGE.jpg" # Path to your image file
    },
    use_cache=True # Speeds up repeated requests
)

# 4. Get your results
print(result)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/lablens_env/lib/python3.12/site-packages/inference_sdk/http/client.py:124, in wrap_errors.<locals>.decorate(*args, **kwargs)
#     123 try:
# --> 124     return function(*args, **kwargs)
#     125 except RetryError as error:
#
# File ~/lablens_env/lib/python3.12/site-packages/inference_sdk/http/client.py:2308, in InferenceHTTPClient.run_workflow(self, workspace_name, workflow_id, specification, images, parameters, excluded_fields, use_cache, enable_profiling, workflow_version_id)
#    2269 """Run inference using a workflow specification.
#    2270
#    2271 Triggers inference from workflow specification at the inference HTTP
#    (...)   2306     HTTPClientError: If there is an error with the server connection.
#    2307 """
# -> 2308 return self._run_workflow(
#    2309     workspace_name=workspace_name,
#    2310     workflow_id=workflow_id,
#    2311     specification=specification,
#    2312     images=images,
#    2313     parameters=parameters,
#    2314     excluded_fields=excluded_fields,
#    2315     legacy_endpoints=False,
#    2316     use_cache=use_cache,
#    2317     enable_profiling=enable_profiling,
#    2318     workflow_version_id=workflow_version_id,
#    2319 )
#
# File ~/lablens_env/lib/python3.12/site-packages/inference_sdk/http/client.py:2334, in InferenceHTTPClient._run_workflow(self, workspace_name, workflow_id, specification, images, parameters, excluded_fields, legacy_endpoints, use_cache, enable_profiling, workflow_version_id)
#    2321 def _run_workflow(
#    2322     self,
#    2323     workspace_name: Optional[str] = None,
#    (...)   2332     workflow_version_id: Optional[str] = None,
#    2333 ) -> List[Dict[str, Any]]:
# -> 2334     response = self._execute_workflow_request(
#    2335         workspace_name=workspace_name,
#    2336         workflow_id=workflow_id,
#    2337         specification=specification,
#    2338         images=images,
#    2339         parameters=parameters,
#    2340         excluded_fields=excluded_fields,
#    2341         legacy_endpoints=legacy_endpoints,
#    2342         use_cache=use_cache,
#    2343         enable_profiling=enable_profiling,
#    2344         workflow_version_id=workflow_version_id,
#    2345     )
#    2346     response_data = response.json()
#
# File ~/lablens_env/lib/python3.12/site-packages/inference_sdk/http/client.py:2417, in InferenceHTTPClient._execute_workflow_request(self, workspace_name, workflow_id, specification, images, parameters, excluded_fields, legacy_endpoints, use_cache, enable_profiling, workflow_version_id)
#    2416         url = f"{self.__api_url}/{workspace_name}/workflows/{workflow_id}"
# -> 2417 response = send_post_request(
#    2418     url=url,
#    2419     payload=payload,
#    2420     headers=DEFAULT_HEADERS,
#    2421     enable_retries=self.__inference_configuration.workflow_run_retries_enabled,
#    2422 )
#    2423 return response
#
# File ~/lablens_env/lib/python3.12/site-packages/backoff/_sync.py:105, in retry_exception.<locals>.retry(*args, **kwargs)
#     104 try:
# --> 105     ret = target(*args, **kwargs)
#     106 except exception as e:
#
# File ~/lablens_env/lib/python3.12/site-packages/inference_sdk/http/utils/executors.py:519, in send_post_request(url, payload, headers, enable_retries)
#     512     raise RetryError(
#     513         (
#     514             "Transient error in HTTP request - response with status code: "
#    (...)    517         status_code=response.status_code,
#     518     )
# --> 519 api_key_safe_raise_for_status(response=response)
#     520 return response
#
# File ~/lablens_env/lib/python3.12/site-packages/inference_sdk/http/utils/requests.py:21, in api_key_safe_raise_for_status(response)
#      20 response.url = deduct_api_key_from_string(value=response.url)
# ---> 21 response.raise_for_status()
#
# File ~/lablens_env/lib/python3.12/site-packages/requests/models.py:1167, in Response.raise_for_status(self)
#    1166 if http_error_msg:
# -> 1167     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://serverless.roboflow.com/mohamed-alwathiq-s-workspace/workflows/petri-dish-contamination-detection-1779520779273
#
# The above exception was the direct cause of the following exception:
#
# HTTPCallErrorError                        Traceback (most recent call last)
# Cell In[18], line 11
#       7     api_key="UFkIgVDpJOe70zZ80m3R"
#       8 )
#       9
#      10 # 3. Run your workflow on an image
# ---> 11 result = client.run_workflow(
#      12     workspace_name="mohamed-alwathiq-s-workspace",
#      13     workflow_id="petri-dish-contamination-detection-1779520779273",
#      14     images={
#
# File ~/lablens_env/lib/python3.12/site-packages/inference_sdk/http/client.py:145, in wrap_errors.<locals>.decorate(*args, **kwargs)
#     143     else:
#     144         api_message = error.response.text
# --> 145     raise HTTPCallErrorError(
#     146         description=str(error),
#     147         status_code=error.response.status_code,
#     148         api_message=api_message,
#     149     ) from error
#     150 except ConnectionError as error:
#     151     raise HTTPClientError(
#     152         f"Error with server connection: {deduct_api_key_from_string(str(error))}"
#     153     ) from error
#
# HTTPCallErrorError: HTTPCallErrorError(description='400 Client Error: Bad Request for url: https://serverless.roboflow.com/mohamed-alwathiq-s-workspace/workflows/petri-dish-contamination-detection-1779520779273', api_message='Failed to assemble `image`. Could not successfully use any deserializer for declared kinds. Details:
# Kind: `image` - Error: Detected runtime parameter `image` defined as `WorkflowImage` that is invalid. Failed on input validation. Details: NumPy image type is not supported in this configuration of `inference`.. More details: None',status_code=400)
